# %%
! pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /Users/masami/.pyenv/versions/3.9.4/lib/python3.9/site-packages (1.5.12)
# Requirement already satisfied: python-slugify in /Users/masami/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: urllib3 in /Users/masami/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from kaggle) (1.26.4)
# Requirement already satisfied: python-dateutil in /Users/masami/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from kaggle) (2.8.1)
# Requirement already satisfied: certifi in /Users/masami/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from kaggle) (2020.12.5)
# Requirement already satisfied: tqdm in /Users/masami/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from kaggle) (4.60.0)
# Requirement already satisfied: six>=1.10 in /Users/masami/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from kaggle) (1.15.0)
# Requirement already satisfied: requests in /Users/masami/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from kaggle) (2.25.1)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/masami/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/masami/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from requests->kaggle) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/masami/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from requests->kaggle) (2.10)

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '../'

# %%
comp_name = "tabular-playground-series-feb-2022"
! kaggle competitions download -c $comp_name
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 ../kaggle.json'
# Downloading tabular-playground-series-feb-2022.zip to /Users/masami/comp/TPS-Feb2022/notebooks
# 100%|████████████████████████████████████████| 267M/267M [00:44<00:00, 6.96MB/s]
# 100%|████████████████████████████████████████| 267M/267M [00:44<00:00, 6.25MB/s]

# %%
! unzip $comp_name -d ../data/raw
# Out:
# Archive:  tabular-playground-series-feb-2022.zip
#   inflating: ../data/raw/sample_submission.csv
#   inflating: ../data/raw/test.csv
#   inflating: ../data/raw/train.csv

# %%
comp_data_zip = f'{comp_name}.zip'
! rm -rf $comp_data_zip
