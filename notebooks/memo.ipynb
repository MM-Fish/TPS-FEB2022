# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
dir_path = '/content/drive/Othercomputers/macbook-air/kaggle-ops/code'
os.chdir(dir_path)

# %%
from base import Feature, get_arguments, generate_features
class survived(Feature):
    def create_features(self):
        self.train['Survived'] = train['Survived']
        create_memo('Survived','生存フラグ。今回の目的変数。')

# %%
import inspect

# %%
for k, v in ({k: v for k, v in globals().items()}).items():
    if inspect.isclass(v) and issubclass(v, Feature) and not inspect.isabstract(v):
        print('get_features if v:{}'.format(v))
# Out:
# get_features if v:<class '__main__.survived'>
